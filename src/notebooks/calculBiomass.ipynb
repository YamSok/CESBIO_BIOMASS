# %% [markdown]
# # REGION OF INTEREST (ROI) - Tracé de l'intensité du l'image corrigée en fonction de la biommasse

# %% [markdown]
#  ### Bibliothèques

# %%
import numpy as np
import matplotlib.pyplot as plt
from plotBiomass import *

# %% [markdown]
# ### Chargement de ROI - COORDONNEES

# %%
def loadParcels(num = None):
    
    if num == None: # On charge toutes les parcelles dans une liste
        parcels = []
        for i in range(1,17):
            #parcels.append(np.loadtxt("../data/16ROI/indcsROI_PAR" +"{:02d}".format(i)+ ".dat"))
            parcels.append(np.loadtxt("indcsROI_PAR" +"{:02d}".format(i)+ ".dat"))
        return [x.astype(int) for x in parcels]
    else: #  On charge uniquemnent la parcelle numéro "num"
        #parcel = np.loadtxt("../data/16ROI/indcsROI_PAR" +"{:02d}".format(num)+ ".dat")
        parcel = np.loadtxt("indcsROI_PAR" +"{:02d}".format(num)+ ".dat")
        return parcel.astype(int)

# %% [markdown]
# ### Chargement des ROI - BIOMASSE

# %%
def loadBiomass(num = None):
    if num == None : 
        bmssList = np.loadtxt("16insituAGB.dat")
    else:
        l = np.loadtxt("16insituAGB.dat")
        bmssList = l[num - 1]
    return bmssList

# %% [markdown]
# ### Affichage des ROI

# %%
def plotParcels(num = None):
    band2 = np.loadtxt("../data/band2.txt")
    #band2x = 10 * np.log(band2)
    plt.figure(1)
    plt.imshow(band2)
    if num == None :
        Parcels = loadParcels()
        for i in range(16):
            X = Parcels[i]
            plt.scatter(X[:,0], X[:,1])
            plt.savefig("parcel.png")
    else:
        X = loadParcels(num)
        print(np.shape(X))
        plt.scatter(X[:,0], X[:,1])
        plt.savefig("parcel.png")

# %%
test = plotParcels()
print(test)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-e96be65d4e84> in <module>
# ----> 1 test = plotParcels()
#       2 print(test)
#
# <ipython-input-4-7a5e8b979546> in plotParcels(num)
#       1 def plotParcels(num = None):
# ----> 2     band2 = np.loadtxt("band2.txt")
#       3     #band2x = 10 * np.log(band2)
#       4     plt.figure(1)
#       5     plt.imshow(band2)
#
# /usr/lib/python3.8/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     979             fname = os_fspath(fname)
#     980         if _is_string_like(fname):
# --> 981             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     982             fencoding = getattr(fh, 'encoding', 'latin1')
#     983             fh = iter(fh)
#
# /usr/lib/python3.8/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
#     268     ds = DataSource(destpath)
# --> 269     return ds.open(path, mode, encoding=encoding, newline=newline)
#     270
#     271
#
# /usr/lib/python3.8/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     621                                       encoding=encoding, newline=newline)
#     622         else:
# --> 623             raise IOError("%s not found." % path)
#     624
#     625
#
# OSError: band2.txt not found.

# %% [markdown]
# ### Moyenne des déplacements

# %%
def mean(tabx,taby):
    Sx,Sy = 0,0
    for i in tabx:
        Sx += i
    for j in taby:
        Sy += j
    mx = Sx/len(tabx)
    my = Sy/len(taby)
    return mx,my

# %%
def shiftImage(mx,my):
    pass

# %% [markdown]
# ### Valeurs des intensités : image BAND 2 corrigée

# %%
def Intensities(band1shiftee,band2):
    band2corr = band2 / band1shiftee
    return band2corr

# %%
band1 = np.loadtxt("band1.txt")
band2 = np.loadtxt("band2.txt")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-0ab7df9d6fb6> in <module>
# ----> 1 band1 = np.loadtxt("band1.txt")
#       2 band2 = np.loadtxt("band2.txt")
#
# ~/.local/lib/python3.8/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     979             fname = os_fspath(fname)
#     980         if _is_string_like(fname):
# --> 981             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     982             fencoding = getattr(fh, 'encoding', 'latin1')
#     983             fh = iter(fh)
#
# ~/.local/lib/python3.8/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
#     268     ds = DataSource(destpath)
# --> 269     return ds.open(path, mode, encoding=encoding, newline=newline)
#     270
#     271
#
# ~/.local/lib/python3.8/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     621                                       encoding=encoding, newline=newline)
#     622         else:
# --> 623             raise IOError("%s not found." % path)
#     624
#     625
#
# OSError: band1.txt not found.

# %%
img = Intensities(band1,band2)
plt.imshow(img)
print(img[500,500])
# Out:
# <ipython-input-8-99ad4811c709>:2: RuntimeWarning: invalid value encountered in true_divide
#   band2corr = band2 / band1shiftee
# 0.11034499890969171

# %% [markdown]
# ### Intensité d'une zone particulière

# %%
def IntensityZone(X,img): # programme juste
    IntTab = []
    n,m = np.shape(X)
    for i in range(n):
        IntTab.append(img[X[i][1],X[i][0]])
    Intmean = np.mean(np.array(IntTab))
    return Intmean, IntTab

# %% [markdown]
# ### Triage des couples Biomasse-Intensité

# %%
def sortBiomInt(BiomassData,IntensityData):
    dataList = []
    finalList = []
    
    for i in range(len(BiomassData)):
        dataList.append( ( BiomassData[i] , IntensityData[i] ) )
    sortedList = sorted(dataList)
    
    for i in range(len(sortedList)):
        finalList.append( [ sortedList[i][0] , sortedList[i][1] ] )
    
    return np.array(finalList)

# %% [markdown]
# ### Programme Principal

# %%
main(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-51cc9975a467> in <module>
# ----> 1 main(img)
#
# NameError: name 'main' is not defined
